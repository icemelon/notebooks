# %% [markdown]
# # Compile BERT from TensorFlow

# %%
import sys
import time
import numpy as np
import tensorflow as tf
import modeling

import tvm
from tvm import relay
from tvm.relay.frontend.tensorflow_parser import TFParser
import tvm.contrib.graph_runtime as runtime
# Out:
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorboard/compat/tensorflow_stub/dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# Download official Tensorflow BERT base model

# %%
# !./download_tf_bert.sh

# %% [markdown]
# Helper function for creating the classification model

# %%
def create_model(bert_config, is_training, input_ids, input_mask, segment_ids,
                 num_labels, use_one_hot_embeddings, use_fp16):
    """Creates a classification model."""
    model = modeling.BertModel(
        config=bert_config,
        is_training=is_training,
        input_ids=input_ids,
        input_mask=input_mask,
        token_type_ids=segment_ids,
        use_one_hot_embeddings=use_one_hot_embeddings,
        compute_type=tf.float16 if use_fp16 else tf.float32)

    # In the demo, we are doing a simple classification task on the entire
    # segment.
    #
    # If you want to use the token-level output, use model.get_sequence_output()
    # instead.
    output_layer = model.get_pooled_output()
    hidden_size = output_layer.shape[-1].value
    output_weights = tf.get_variable(
        "output_weights", [num_labels, hidden_size],
        initializer=tf.truncated_normal_initializer(stddev=0.02))
    output_bias = tf.get_variable(
        "output_bias", [num_labels], initializer=tf.zeros_initializer())

    with tf.variable_scope("loss"):
        if is_training:
            # I.e., 0.1 dropout
            output_layer = tf.nn.dropout(output_layer, keep_prob=0.9)
        logits = tf.matmul(output_layer, output_weights, transpose_b=True)
        logits = tf.nn.bias_add(logits, output_bias, name='cls_logits')
        probabilities = tf.nn.softmax(logits, axis=-1, name='cls_probabilities')
    return probabilities

# %% [markdown]
# Configuation of the BERT model

# %%
batch = 1
seq_length = 32
num_labels = 2
use_fp16 = False
ckpt_file = "uncased_L-12_H-768_A-12/bert_model.ckpt"
bert_config = modeling.BertConfig.from_json_file("uncased_L-12_H-768_A-12/bert_config.json")
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W1115 19:23:00.853036 140291125999424 deprecation_wrapper.py:119] From /home/ubuntu/repo/notebooks/bert/modeling.py:94: The name tf.gfile.GFile is deprecated. Please use tf.io.gfile.GFile instead.

# %% [markdown]
# Create TF model and load from checkpoint.

# %%
shape = (batch, seq_length)
input_ids = tf.placeholder(tf.int32, shape, 'input_ids')
input_mask = tf.placeholder(tf.int32, shape, 'input_mask')
segment_ids = tf.placeholder(tf.int32, shape, 'segment_ids')

tf_model = create_model(bert_config, False, input_ids, input_mask, segment_ids,
                        num_labels, False, use_fp16)
# Out:
# W1115 19:23:00.890331 140291125999424 deprecation_wrapper.py:119] From /home/ubuntu/repo/notebooks/bert/modeling.py:176: The name tf.variable_scope is deprecated. Please use tf.compat.v1.variable_scope instead.
#
# W1115 19:23:00.893841 140291125999424 deprecation_wrapper.py:119] From /home/ubuntu/repo/notebooks/bert/modeling.py:427: The name tf.get_variable is deprecated. Please use tf.compat.v1.get_variable instead.
#
# W1115 19:23:01.656079 140291125999424 lazy_loader.py:50]
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# W1115 19:23:01.679353 140291125999424 deprecation.py:323] From /home/ubuntu/repo/notebooks/bert/modeling.py:683: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.

# %%
# Load model from checkpoint
tf_config = tf.ConfigProto()
tf_config.gpu_options.visible_device_list = "0"
tf_config.gpu_options.allow_growth = True
tf_sess = tf.Session(config=tf_config)

tvars = tf.trainable_variables()
(assignment_map, initialized_variable_names) = modeling.get_assignment_map_from_checkpoint(tvars, ckpt_file)
tf.train.init_from_checkpoint(ckpt_file, assignment_map)
tf_sess.run(tf.global_variables_initializer())

# %% [markdown]
# Run and benchmark the BERT model

# %%
input_ids_data = np.random.uniform(size=shape).astype('int32')
input_mask_data = np.ones(shape).astype('int32')
segment_ids_data = np.zeros(shape).astype('int32')

input_dict = {input_ids: input_ids_data, input_mask: input_mask_data, segment_ids: segment_ids_data}
tf_out = tf_sess.run(tf_model, input_dict)
print(tf_out)
# Out:
# [[0.4380299 0.5619701]]

# %%
# dry run
for _ in range(10):
    tf_sess.run(tf_model, input_dict)

min_repeat_ms = 2000
number = 20
while True:
    beg = time.time()
    for _ in range(number):
        tf_sess.run(tf_model, input_dict)
    end = time.time()
    lat = (end - beg) * 1e3
    if lat >= min_repeat_ms:
        break
    number = int(max(min_repeat_ms / (lat / number) + 1, number * 1.618))
print('TF latency for seq length %s: %.2f ms' % (seq_length, lat / number))
# Out:
# TF latency for seq length 32: 6.92 ms

# %% [markdown]
# ## Compile TF BERT using TVM

# %% [markdown]
# First convert to frozen model and export to file.

# %%
output_node_names = ['loss/cls_probabilities']
frozen_file = "tf_frozen_bert.pb"

tf.logging.info("**** Trainable Variables ****")
for var in tvars:
    init_string = ""
    if var.name in initialized_variable_names:
        init_string = ", *INIT_FROM_CKPT*"
    else:
        init_string = ", *NOTTTTTTTTTTTTTTTTTTTTT"
        tf.logging.info("  name = %s, shape = %s%s", var.name, var.shape, init_string)

frozen_graph = tf.graph_util.convert_variables_to_constants(
    tf_sess, tf_sess.graph.as_graph_def(), output_node_names)

num_nodes = len(frozen_graph.node)
from tensorflow.python.compiler.tensorrt import trt_convert as trt
converter = trt.TrtGraphConverter(
    input_graph_def=frozen_graph,
    nodes_blacklist=output_node_names,
    max_workspace_size_bytes=(4096 << 20) - 1000,
    precision_mode = "FP16" if use_fp16 else "FP32",
    minimum_segment_size=4,
    is_dynamic_op=True,
    maximum_cached_engines=1000
)
frozen_graph = converter.convert()

print('Total node count before and after TF-TRT conversion:',
      num_nodes, '->', len(frozen_graph.node))
with tf.gfile.GFile(frozen_file, "wb") as f:
    f.write(frozen_graph.SerializeToString())
print("export frozen model to %s" % frozen_file)
# Out:
# W1115 19:23:13.024651 140291125999424 deprecation.py:323] From <ipython-input-9-1ec1d989451e>:14: convert_variables_to_constants (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.convert_variables_to_constants`
# W1115 19:23:13.025627 140291125999424 deprecation.py:323] From /home/ubuntu/anaconda3/lib/python3.7/site-packages/tensorflow/python/framework/graph_util_impl.py:270: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.compat.v1.graph_util.extract_sub_graph`
# Total node count before and after TF-TRT conversion: 1454 -> 1248
# export frozen model to tf_frozen_bert.pb

# %% [markdown]
# Convert the frozen model to Relay

# %%
parser = TFParser(frozen_file)
graph_def = parser.parse()
mod, params = relay.frontend.from_tensorflow(graph_def, outputs=output_node_names)
# Out:
# W1115 19:23:42.291382 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:42.292312 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:42.292924 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:42.293588 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:42.294254 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:42.294961 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:42.412743 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:42.413674 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:42.414828 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:42.415477 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:42.416095 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:42.416784 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:42.536332 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:42.537190 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:42.537801 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:42.538446 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:42.539138 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:42.540931 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:42.658015 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:42.658870 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:42.659451 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:42.660091 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:42.660823 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:42.661456 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:42.779335 140291125999424 common.py:398] Attribute Taxis is ignored in relay.sym.take
# W1115 19:23:42.780182 140291125999424 common.py:398] Attribute batch_dims is ignored in relay.sym.take
# W1115 19:23:42.780762 140291125999424 common.py:398] Attribute Tindices is ignored in relay.sym.take
# W1115 19:23:42.781392 140291125999424 common.py:398] Attribute Tparams is ignored in relay.sym.take
# W1115 19:23:42.782094 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.take
# W1115 19:23:42.782741 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.take
# W1115 19:23:42.783439 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.take
# W1115 19:23:42.784133 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.take
# W1115 19:23:42.901139 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:42.902061 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:42.902693 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:42.903379 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:42.904043 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:42.904680 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.021530 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.022429 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.022988 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.023676 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.024330 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.024988 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.143385 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.144241 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.144791 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.145434 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.146157 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.146862 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.263556 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.264426 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.265014 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.265689 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.266352 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.267053 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.387083 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.387937 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.388520 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.389135 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.389883 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.390513 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.507941 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.508780 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.509361 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.509981 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.510420 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.510908 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.628074 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.628911 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.629435 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.629967 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.630410 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.630889 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.746838 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.747707 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.748180 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.748646 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.749109 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.749685 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.866663 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.867774 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.868236 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.868732 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.869687 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.870357 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.988509 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:43.989342 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:43.989902 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:43.990346 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:43.990802 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:43.991231 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:44.107997 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:44.108850 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:44.109356 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:44.109883 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:44.110374 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:44.110808 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:44.227707 140291125999424 common.py:398] Attribute Tdim is ignored in relay.sym.expand_dims
# W1115 19:23:44.228564 140291125999424 common.py:398] Attribute T is ignored in relay.sym.expand_dims
# W1115 19:23:44.229080 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:44.229548 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.expand_dims
# W1115 19:23:44.230030 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.expand_dims
# W1115 19:23:44.230479 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.expand_dims
# W1115 19:23:44.348365 140291125999424 common.py:398] Attribute Taxis is ignored in relay.sym.take
# W1115 19:23:44.349211 140291125999424 common.py:398] Attribute batch_dims is ignored in relay.sym.take
# W1115 19:23:44.349796 140291125999424 common.py:398] Attribute Tindices is ignored in relay.sym.take
# W1115 19:23:44.350697 140291125999424 common.py:398] Attribute Tparams is ignored in relay.sym.take
# W1115 19:23:44.351383 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.take
# W1115 19:23:44.351830 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.take
# W1115 19:23:44.352250 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.take
# W1115 19:23:44.352720 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.take
# W1115 19:23:44.471969 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:44.472801 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:44.473340 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:44.473842 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:44.474882 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:44.475300 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:45.990594 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:45.991458 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:45.991996 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:45.992453 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:45.992964 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:45.993670 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:47.754161 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:47.755038 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:47.755567 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:47.756067 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:47.756544 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:47.757005 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:48.112393 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:48.113229 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:48.113821 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:48.114256 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:48.114706 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:48.115193 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:48.350747 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:23:48.351582 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:23:48.352102 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:23:48.352992 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:23:48.353696 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:23:49.061526 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:49.062392 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:49.062904 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:49.063390 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:49.064387 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:49.064831 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:49.185265 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:49.186099 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:49.186631 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:49.187535 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:49.187970 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:49.188422 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:49.188894 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:49.308468 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:49.309312 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:49.309845 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:49.310330 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:49.310800 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:49.311897 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:49.312530 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:49.431473 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:49.432311 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:49.432826 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:49.433293 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:49.433827 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:49.434939 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:49.435408 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:49.910645 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:49.911517 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:49.911998 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:49.912431 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:49.912898 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:49.913373 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:50.034642 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:50.035466 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:50.035990 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:50.036458 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:50.036906 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:50.038058 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:50.160144 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:50.160980 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:50.161512 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:50.161937 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:50.162396 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:50.162852 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:51.000972 140291125999424 common.py:398] Attribute T is ignored in relay.sym.softmax
# W1115 19:23:51.001909 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.softmax
# W1115 19:23:51.002472 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.softmax
# W1115 19:23:51.002910 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.softmax
# W1115 19:23:51.003394 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.softmax
# W1115 19:23:51.365080 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:51.365984 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:51.366497 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:51.366981 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:51.367836 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:51.368242 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:51.492700 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:51.493546 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:51.494080 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:51.494542 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:51.495004 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:51.495473 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:51.495921 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:51.860998 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:51.861901 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:51.862414 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:51.862885 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:51.863346 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:51.863814 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:52.228806 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:52.229691 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:52.230205 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:52.230673 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:52.231100 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:52.231561 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:52.478068 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:23:52.478896 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:23:52.479405 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:23:52.479867 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:23:52.480330 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:23:53.205868 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:53.206746 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:53.207219 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:53.207680 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:53.208168 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:53.209270 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:53.209974 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:53.934586 140291125999424 common.py:398] Attribute T is ignored in relay.sym.tanh
# W1115 19:23:53.935441 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.tanh
# W1115 19:23:53.935973 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.tanh
# W1115 19:23:53.936408 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.tanh
# W1115 19:23:53.936868 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.tanh
# W1115 19:23:54.426007 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:54.426876 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:54.427381 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:54.427855 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:54.428299 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:54.429419 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:54.430124 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:54.792647 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:54.793493 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:54.793970 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:54.794427 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:54.794891 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:54.795362 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:55.162703 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:55.163580 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:55.164041 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:55.164525 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:55.164958 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:55.165451 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:55.411185 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:23:55.412270 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:23:55.412939 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:23:55.413376 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:23:55.414224 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:23:56.152889 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:56.153819 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:56.154358 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:56.154860 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:56.155289 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:56.155764 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:56.156200 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:56.279519 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:56.280344 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:56.280862 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:56.281312 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:56.281825 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:56.282300 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:56.282784 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:56.407526 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:56.408370 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:56.408888 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:56.409352 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:56.409877 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:56.410403 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:56.410853 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:56.900165 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:56.901008 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:56.901533 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:56.902008 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:56.902465 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:56.902912 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:57.028147 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:57.029011 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:57.029476 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:57.029938 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:57.030395 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:57.030865 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:57.155544 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:57.156373 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:57.156895 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:57.157355 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:57.157861 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:57.158365 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:58.022522 140291125999424 common.py:398] Attribute T is ignored in relay.sym.softmax
# W1115 19:23:58.023441 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.softmax
# W1115 19:23:58.023908 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.softmax
# W1115 19:23:58.024364 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.softmax
# W1115 19:23:58.024824 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.softmax
# W1115 19:23:58.397967 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:23:58.398792 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:23:58.399318 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:23:58.399781 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:23:58.400247 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:23:58.400720 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:23:58.527595 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:23:58.528456 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:23:58.528964 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:23:58.529410 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:23:58.529910 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:23:58.530380 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:23:58.530863 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:23:58.903948 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:58.904785 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:58.905298 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:58.905811 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:58.906301 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:58.906740 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:59.279795 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:23:59.280655 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:23:59.281195 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:23:59.282163 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:23:59.282632 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:23:59.283109 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:23:59.534487 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:23:59.535336 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:23:59.535848 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:23:59.536319 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:23:59.536772 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:24:00.292284 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:00.293210 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:00.293761 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:00.294225 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:00.294666 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:00.295160 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:00.295598 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:01.051135 140291125999424 common.py:398] Attribute T is ignored in relay.sym.tanh
# W1115 19:24:01.052042 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.tanh
# W1115 19:24:01.052606 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.tanh
# W1115 19:24:01.053063 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.tanh
# W1115 19:24:01.053538 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.tanh
# W1115 19:24:01.558767 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:01.559662 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:01.560183 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:01.560664 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:01.561138 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:01.561605 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:01.562090 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:01.942116 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:24:01.942979 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:24:01.943549 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:24:01.944024 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:24:01.945080 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:24:01.945518 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:24:02.325677 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:24:02.326600 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:24:02.327080 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:24:02.327581 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:24:02.328048 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:24:02.328512 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:24:02.583578 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:24:02.584703 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:24:02.585184 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:24:02.585674 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:24:02.586173 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:24:03.355176 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:03.356096 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:03.356612 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:03.357092 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:03.357589 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:03.358023 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:03.358471 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:03.488703 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:03.489532 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:03.490039 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:03.490515 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:03.491292 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:03.492207 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:03.492656 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:03.620349 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:03.621215 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:03.621792 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:03.622233 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:03.622696 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:03.623195 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:03.623637 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:04.126801 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:24:04.127672 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:24:04.128144 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:24:04.128622 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:24:04.129072 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:24:04.130272 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:24:04.259068 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:24:04.259914 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:24:04.260443 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:24:04.261356 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:24:04.261838 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:24:04.262356 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:24:04.390674 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:24:04.391557 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:24:04.392026 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:24:04.392521 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:24:04.392964 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:24:04.393438 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:24:05.289386 140291125999424 common.py:398] Attribute T is ignored in relay.sym.softmax
# W1115 19:24:05.290317 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.softmax
# W1115 19:24:05.290868 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.softmax
# W1115 19:24:05.291373 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.softmax
# W1115 19:24:05.292175 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.softmax
# W1115 19:24:05.680932 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:24:05.681862 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:24:05.682431 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:24:05.683374 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:24:05.683847 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:24:05.684327 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:24:05.817807 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:05.818644 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:05.819166 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:05.819638 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:05.820115 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:05.820586 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:05.821091 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:06.207603 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:24:06.208471 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:24:06.209002 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:24:06.209491 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:24:06.209937 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:24:06.210419 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:24:06.599157 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:24:06.600021 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:24:06.600541 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:24:06.601013 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:24:06.601519 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:24:06.601951 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:24:06.859386 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:24:06.860249 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:24:06.860819 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:24:06.861299 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:24:06.861802 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:24:07.638758 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:24:07.639641 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:07.640190 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:07.640632 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:24:07.641119 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:24:07.642253 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:24:07.642721 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:24:08.419012 140291125999424 common.py:398] Attribute T is ignored in relay.sym.tanh
# W1115 19:24:08.419914 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.tanh
# W1115 19:24:08.420438 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.tanh
# W1115 19:24:08.420902 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.tanh
# W1115 19:24:08.421383 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.tanh
# W1115 19:24:08.941890 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:24:08.942749 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:24:08.943290 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# ...
# W1115 19:25:18.910575 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:25:18.911065 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:25:18.911575 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:25:19.253475 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:25:19.254374 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:25:19.254843 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:25:19.255334 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:25:19.255855 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:25:20.275857 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:20.276735 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:20.277276 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:20.277832 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:20.278275 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:20.278780 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:20.279276 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:20.450601 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:20.451426 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:20.452003 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:20.452445 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:20.452933 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:20.453418 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:20.453985 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:20.628207 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:20.629104 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:20.629688 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:20.630650 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:20.631098 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:20.631596 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:20.632080 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:21.312728 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:25:21.313583 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:25:21.314115 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:25:21.314609 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:25:21.315115 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:25:21.315617 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:25:21.487608 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:25:21.488427 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:25:21.488963 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:25:21.489407 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:25:21.489951 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:25:21.490470 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:25:21.664384 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:25:21.665243 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:25:21.665859 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:25:21.666818 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:25:21.667284 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:25:21.667739 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:25:22.871941 140291125999424 common.py:398] Attribute T is ignored in relay.sym.softmax
# W1115 19:25:22.872830 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.softmax
# W1115 19:25:22.873394 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.softmax
# W1115 19:25:22.873959 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.softmax
# W1115 19:25:22.874430 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.softmax
# W1115 19:25:23.390210 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:25:23.391064 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:25:23.391613 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:25:23.392114 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:25:23.392586 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:25:23.393021 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:25:23.568807 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:23.569720 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:23.570261 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:23.570714 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:23.571199 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:23.571685 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:23.572184 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:24.083517 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:25:24.084406 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:25:24.084973 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:25:24.085479 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:25:24.085974 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:25:24.086462 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:25:24.606302 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:25:24.607183 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:25:24.607733 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:25:24.608699 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:25:24.609138 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:25:24.609680 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:25:24.954646 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:25:24.955509 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:25:24.956034 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:25:24.956524 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:25:24.957048 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:25:25.999637 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:26.000550 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:26.001107 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:26.002210 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:26.002665 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:26.003178 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:26.003681 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:27.043244 140291125999424 common.py:398] Attribute T is ignored in relay.sym.tanh
# W1115 19:25:27.044131 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.tanh
# W1115 19:25:27.044686 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.tanh
# W1115 19:25:27.045192 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.tanh
# W1115 19:25:27.045724 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.tanh
# W1115 19:25:27.744626 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:27.745513 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:27.746085 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:27.746541 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:27.747048 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:27.747482 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:27.747981 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:28.272212 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:25:28.273071 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:25:28.273695 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:25:28.274659 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:25:28.275098 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:25:28.275631 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:25:28.798557 140291125999424 common.py:398] Attribute Tidx is ignored in relay.sym.mean
# W1115 19:25:28.799413 140291125999424 common.py:398] Attribute T is ignored in relay.sym.mean
# W1115 19:25:28.799979 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.mean
# W1115 19:25:28.800443 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.mean
# W1115 19:25:28.800948 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.mean
# W1115 19:25:28.801384 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.mean
# W1115 19:25:29.152597 140291125999424 common.py:398] Attribute T is ignored in relay.sym.power
# W1115 19:25:29.153483 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.power
# W1115 19:25:29.154044 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.power
# W1115 19:25:29.154988 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.power
# W1115 19:25:29.155425 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.power
# W1115 19:25:30.209529 140291125999424 common.py:398] Attribute Tshape is ignored in relay.sym.reshape
# W1115 19:25:30.210489 140291125999424 common.py:398] Attribute T is ignored in relay.sym.reshape
# W1115 19:25:30.210960 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.reshape
# W1115 19:25:30.211489 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.reshape
# W1115 19:25:30.212175 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.reshape
# W1115 19:25:30.213181 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.reshape
# W1115 19:25:30.746410 140291125999424 common.py:398] Attribute T is ignored in relay.sym.squeeze
# W1115 19:25:30.747431 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.squeeze
# W1115 19:25:30.747914 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.squeeze
# W1115 19:25:30.748426 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.squeeze
# W1115 19:25:30.748918 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.squeeze
# W1115 19:25:30.933349 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:30.934211 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:30.934796 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:30.935242 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:30.935760 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:30.936201 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:30.936702 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:31.288136 140291125999424 common.py:398] Attribute T is ignored in relay.sym.tanh
# W1115 19:25:31.288996 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.tanh
# W1115 19:25:31.289560 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.tanh
# W1115 19:25:31.290047 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.tanh
# W1115 19:25:31.290539 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.tanh
# W1115 19:25:31.467897 140291125999424 common.py:398] Attribute T is ignored in relay.sym.dense
# W1115 19:25:31.468758 140291125999424 common.py:398] Attribute transpose_a is ignored in relay.sym.dense
# W1115 19:25:31.469575 140291125999424 common.py:398] Attribute transpose_b is ignored in relay.sym.dense
# W1115 19:25:31.470029 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.dense
# W1115 19:25:31.470478 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.dense
# W1115 19:25:31.470967 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.dense
# W1115 19:25:31.471466 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.dense
# W1115 19:25:31.822417 140291125999424 common.py:398] Attribute T is ignored in relay.sym.softmax
# W1115 19:25:31.823310 140291125999424 common.py:398] Attribute _output_shapes is ignored in relay.sym.softmax
# W1115 19:25:31.823857 140291125999424 common.py:398] Attribute _node_name is ignored in relay.sym.softmax
# W1115 19:25:31.824354 140291125999424 common.py:398] Attribute _target_layout is ignored in relay.sym.softmax
# W1115 19:25:31.824795 140291125999424 common.py:398] Attribute _input_shapes is ignored in relay.sym.softmax

# %% [markdown]
# Compile the graph and benchmark

# %%
target = 'cuda -libs=cublas'
ctx = tvm.gpu(0)
with relay.build_config(opt_level=3):
    graph, lib, new_params = relay.build(mod["main"], target, params=params)

ex = runtime.create(graph, lib, ctx)
ex.set_input(**new_params)
ex.set_input(input_ids=input_ids_data, segment_ids=segment_ids_data, input_mask=input_mask_data)
ex.run()
out = ex.get_output(0)
print(out)

## check correctness
tvm.testing.assert_allclose(out.asnumpy(), tf_out, rtol=1e-5)
# Out:
# W1115 19:25:33.311585 140291125999424 dispatcher.py:541] Cannot find config for target=cuda -libs=cublas, workload=('dense', (1, 768, 'float32'), (2, 768, 'float32'), 0, 'float32'). A fallback configuration is used, which may bring great performance regression.
# W1115 19:25:33.319668 140291125999424 dispatcher.py:541] Cannot find config for target=cuda -libs=cublas, workload=('dense', (1, 768, 'float32'), (768, 768, 'float32'), 0, 'float32'). A fallback configuration is used, which may bring great performance regression.
# W1115 19:25:33.337387 140291125999424 dispatcher.py:541] Cannot find config for target=cuda -libs=cublas, workload=('dense', (32, 3072, 'float32'), (768, 3072, 'float32'), 0, 'float32'). A fallback configuration is used, which may bring great performance regression.
# W1115 19:25:33.348151 140291125999424 dispatcher.py:541] Cannot find config for target=cuda -libs=cublas, workload=('dense', (32, 768, 'float32'), (3072, 768, 'float32'), 0, 'float32'). A fallback configuration is used, which may bring great performance regression.
# W1115 19:25:33.372719 140291125999424 dispatcher.py:541] Cannot find config for target=cuda -libs=cublas, workload=('dense', (32, 768, 'float32'), (768, 768, 'float32'), 0, 'float32'). A fallback configuration is used, which may bring great performance regression.
# [[0.43802983 0.5619702 ]]

# %%
## benchmark
ftimer = ex.module.time_evaluator("run", ctx, min_repeat_ms=2000)
prof_res = np.array(ftimer().results) * 1000  # convert to millisecond
print("TVM latency for seq length %s: %.2f ms" % (seq_length, np.mean(prof_res)))
# Out:
# TVM latency for seq length 32: 3.12 ms
